# %% [markdown]
# # RobustModelMaker Testing Suite

# %% [markdown]
# ### Unit Tests

# %%
import sys
#sys.path.append(r"path_to_your_code_directory")
sys.path.append(r"C:\Users\Amanda\Favorites\Machine Learning\RobustModelMaker")
from RobustModelMaker import *
import pytest
import os
os.environ["RUN_PERFORMANCE"] = "1"

# %%
pytest.main([
    "-vv",
    "-s",
    "unit_test_suite.py"
])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\RobustModelMaker\tests
# plugins: anyio-3.5.0
# collecting ... collected 102 items
#
# unit_test_suite.py::test_module_imports_and_public_api PASSED
# unit_test_suite.py::test_all_algorithm_configs_exist[binary-eln] PASSED
# unit_test_suite.py::test_all_algorithm_configs_exist[binary-rf] PASSED
# unit_test_suite.py::test_all_algorithm_configs_exist[binary-xgb] PASSED
# unit_test_suite.py::test_all_algorithm_configs_exist[binary-mlp] PASSED
# unit_test_suite.py::test_all_algorithm_configs_exist[binary-svm] PASSED
# unit_test_suite.py::test_all_algorithm_configs_exist[binary-rdg] PASSED
# unit_test_suite.py::test_all_algorithm_configs_exist[binary-las] PASSED
# ...

# %% [markdown]
# ### Performance Tests

# %%
pytest.main(["-q", "performance_test_suite.py", "-s", "-vv"])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\RobustModelMaker\tests
# plugins: anyio-3.5.0
# collecting ... collected 28 items
#
# performance_test_suite.py::test_binary_fit_predict_performance_fast[log] PASSED
# performance_test_suite.py::test_binary_fit_predict_performance_fast[rdg] PASSED
# performance_test_suite.py::test_binary_fit_predict_performance_fast[las] PASSED
# performance_test_suite.py::test_binary_fit_predict_performance_fast[svm] PASSED
# performance_test_suite.py::test_binary_fit_predict_performance_fast[eln] PASSED
# performance_test_suite.py::test_binary_fit_predict_performance_fast[rf] PASSED
# performance_test_suite.py::test_multiclass_fit_predict_performance_fast[log] PASSED
# ...

# %% [markdown]
# ### Reproducibility Tests

# %%
pytest.main(["-q", "reproducibility_test_suite.py", "-s", "-vv"])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\RobustModelMaker\tests
# plugins: anyio-3.5.0
# collecting ... collected 30 items
#
# reproducibility_test_suite.py::TestExactReproducibility::test_binary_selected_features_identical PASSED
# reproducibility_test_suite.py::TestExactReproducibility::test_binary_fold_scores_identical PASSED
# reproducibility_test_suite.py::TestExactReproducibility::test_binary_mean_score_identical PASSED
# reproducibility_test_suite.py::TestExactReproducibility::test_binary_stability_frequencies_identical PASSED
# reproducibility_test_suite.py::TestExactReproducibility::test_regression_selected_features_identical PASSED
# ...
